# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
laser=pd.read_csv('TrackerZ1 - Sheet1.csv')
#laser.head()
#plt.plot(laser['x'],laser['luma'])

fig = plt.figure(figsize=(14,8))
ax = plt.axes(projection="3d")
ax.scatter(laser['x'], laser['y'], -1*laser['luma'], color='blue')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('luma')

plt.show()

# %%
fig = plt.figure(figsize=(12,5))
ax1 = plt.axes()
ax2 = plt.axes()
ax1.scatter(laser['x'], -1*laser['luma'], color='green')
ax2.scatter(laser['y'],-1*laser['luma'],color='blue')
ax1.plot()
ax2.plot()
# Out:
# []

# %%
from PIL import Image

# %%
import numpy as np

# %%
im=Image.open('12 (2).jpg','r')

# %%
pix_val=list(im.getdata())
pix_val[276207]
width, height=im.size
print(width,height)
# Out:
# 488 566

# %%
luma=[]
for i in range (0,len(pix_val)):
  k=0.2126*int(pix_val[i][0])+0.7152*int(pix_val[i][1])+0.0722*int(pix_val[i][2])
  luma.append(-1*k)

# %%
x=np.reshape(luma,(height,width))

# %%
from matplotlib import cm
fig = plt.figure(figsize=(14,6))
ax = plt.axes(projection="3d")
k=np.linspace(0,height,height)
m=np.linspace(0,width,width)
X,Y=np.meshgrid(k,m)
ax.plot_surface(Y,X,x.T,cmap=cm.coolwarm,linewidth=0, antialiased=False)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('luma')

plt.show()

# %%
red=[]
for i in range (0,len(pix_val)):
  r=pix_val[i][0]
  red.append(r)

# %%
R=np.reshape(red,(height,width))

# %%
from matplotlib import cm
fig = plt.figure(figsize=(14,6))
ax = plt.axes(projection="3d")
k=np.linspace(0,height,height)
m=np.linspace(0,width,width)
X,Y=np.meshgrid(k,m)
ax.plot_surface(Y,X,R.T,cmap=cm.coolwarm,linewidth=0, antialiased=False)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('red')

plt.show()
plt.savefig("tracker_z1_plot.jpg")

# %%
xybar=np.mean(x)
xycovar=np.cov(x)

# %%
from matplotlib import cm
fig = plt.figure(figsize=(14,6))
ax = plt.axes(projection="3d")
k=np.linspace(0,height,height)
m=np.linspace(0,width,width)
X,Y=np.meshgrid(k,m)
ax.contour3D(Y,X,R.T,cmap=cm.coolwarm)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('red')

plt.show()

# %%
def twoD_Gauss(x,y,amplitude,x0,y0,sigma_x,sigma_y,offset):
    x0=float(x0)
    y0=float(y0)
    return offset + amplitude*np.exp(-(((x-x0)**(2)/(2*sigma_x**(2))) + ((y-y0)**(2)/(2*sigma_y**(2)))))

# %%
from matplotlib import cm
fig = plt.figure(figsize=(14,6))
ax = plt.axes(projection="3d")
k=np.linspace(0,height,height)
m=np.linspace(0,width,width)
X,Y=np.meshgrid(k,m)
ax.contour3D(Y,X,x.T)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('luma')

plt.show()

# %%
def func(data, a, b):
    return data[:,0]*data[:,1]*a + b

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
from scipy.stats import multivariate_normal

x, y = np.mgrid[-1.0:1.0:30j, -1.0:1.0:30j]

# Need an (N, 2) array of (x, y) pairs.
xy = np.column_stack([x.flat, y.flat])

mu = np.array([0.0, 0.0])

sigma = np.array([.5, .5])
covariance = np.diag(sigma**2)

z = multivariate_normal.pdf(xy, mean=mu, cov=covariance)

# Reshape back to a (30, 30) grid.
z = z.reshape(x.shape)





fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')



ax.plot_surface(x,y,z,cmap=cm.coolwarm,linewidth=0, antialiased=False)
#ax.plot_wireframe(x,y,z)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
import numpy as np
from scipy.stats import multivariate_normal




#Parameters to set
mu_x = 0
variance_x = 3

mu_y = 0
variance_y = 15

x = np.linspace(-10,10,500)
y = np.linspace(-10,10,500)
X,Y = np.meshgrid(x,y)

pos = np.array([X.flatten(),Y.flatten()]).T



rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])


fig = plt.figure(figsize=(10,10))
ax0 = fig.add_subplot(111)
ax0.contour(X, Y, rv.pdf(pos).reshape(500,500))

plt.show()

# %%
import numpy as np
from PIL import Image
im=Image.open('tracker_z1.jpg','r')
pix_val=list(im.getdata())
#pix_val[276207]
width, height=im.size

# %%
luma=[]
for i in range (0,len(pix_val)):
  k=0.2126*int(pix_val[i][0])+0.7152*int(pix_val[i][1])+0.0722*int(pix_val[i][2])
  luma.append(-1*k)

# %%
x=np.reshape(luma,(height,width))

# %%
from matplotlib import cm
fig = plt.figure(figsize=(14,6))
ax = plt.axes(projection="3d")
k=np.linspace(0,height,height)
m=np.linspace(0,width,width)
X,Y=np.meshgrid(k,m)
ax.plot_surface(Y,X,x2.T,cmap=cm.coolwarm,linewidth=0, antialiased=False)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('luma')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-0765b3796fed> in <module>
#       5 m=np.linspace(0,width,width)
#       6 X,Y=np.meshgrid(k,m)
# ----> 7 ax.plot_surface(Y,X,x2.T,cmap=cm.coolwarm,linewidth=0, antialiased=False)
#       8
#       9 ax.set_xlabel('x')
#
# c:\users\ashish\appdata\local\programs\python\python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\users\ashish\appdata\local\programs\python\python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1663
#    1664         # TODO: Support masked arrays
# ...
